# %%
import pandas as pd

# %%
# %store -r data_df

# %%
series = data_df['Nord Pool Lietuva']

# %% [markdown]
# # Duomenų žvalgomoji analize

# %% [markdown]
# Šio darbo metu analizuojami Lietuvos elektros kainos bei su elektros tiekimu, gamyba bei prekyba susiję duomenys. Duomenų šaltinis - Litgrid oficialus elektros tiekimo dabartinės bei istorinės informacijos puslapis. Originalūs duomenys pateikiami valandiniu dažnumu. Iš viso buvo analizuojami šie duomenys:

# %%
data_df.describe()
# Out:
#        Nord Pool Lietuva  decomposition_residuals_365d  \
# count        2191.000000                   1827.000000
# mean           40.319849                     -0.027507
# std            11.831736                      8.420065
# min             0.000000                    -39.510707
# 25%            32.520833                     -4.839248
# 50%            39.041667                     -0.230730
# 75%            46.958333                      4.523809
# max           115.208333                     64.657068
#
#        decomposition_residuals_365d_7d  decomposition_residuals_7d
# count                      1821.000000                 2185.000000
# mean                         -0.000145                   -0.003847
# std                           5.330639                    5.753759
# min                         -36.984025                  -48.676528
# 25%                          -2.658509                   -2.696599
# 50%                          -0.145779                   -0.279932
# 75%                           2.584115                    2.411563
# max                          40.802485                   52.306611

# %%
series.plot(title='Nord Pool Lietuva - Elektros kaina', figsize=(24,6))
# Out:
# <AxesSubplot:title={'center':'Nord Pool Lietuva - Elektros kaina'}, xlabel='Time'>
